# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import random
from sklearn import datasets, svm, tree, preprocessing, metrics

# %%
china = pd.read_csv('./data/china_gdp.csv')

# %%
china.head()
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %%
plt.figure(figsize=(15, 10))
plt.xlabel("Year")
plt.ylabel("GDP")
plt.scatter(china['Year'], china['Value'])

plt.show()
